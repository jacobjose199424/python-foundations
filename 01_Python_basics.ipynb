# %% [markdown]
# <a href="https://colab.research.google.com/github/jacobjose199424/python-foundations/blob/main/01_Python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Python Basics
# ##1)Sum

# %%
x=10
y=15
print("sum:",x+y)
# Out:
# sum: 25

# %% [markdown]
# ##2)For loop:
# *This code uses a for loop to iterate five times. In each iteration, it prints the string "Learning python steps:" followed by the current value of the loop variable i. The variable i will take on values from 0 to 4.*

# %%
for i in range(5):
  print("Learning python steps:",i)
# Out:
# Learning python steps: 0
# Learning python steps: 1
# Learning python steps: 2
# Learning python steps: 3
# Learning python steps: 4
